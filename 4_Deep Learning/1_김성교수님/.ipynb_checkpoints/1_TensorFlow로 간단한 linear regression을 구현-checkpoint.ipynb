# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Hypothesis and cost function
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1) x_train // y_train
# ## 2) our hypothesis 설정.

# %%
import tensorflow as tf

## X and Y data
x_train = [1, 2, 3]
y_train = [1, 2, 3]

W = tf.Variable(tf.random.normal([1]), name = 'weight')
b = tf.Variable(tf.random.normal([1]), name = 'bias')

print('W와 b의 데이터 확인:', W, b)
print('W와 b의 데이터 모양:',W.shape, b.shape)

## our hypothesis [XW + b]
hypothesis = x_train * W + b
# Out:
# W와 b의 데이터 확인: <tf.Variable 'weight:0' shape=(1,) dtype=float32, numpy=array([1.3721056], dtype=float32)> <tf.Variable 'bias:0' shape=(1,) dtype=float32, numpy=array([1.1031245], dtype=float32)>
# W와 b의 데이터 모양: (1,) (1,)

# %% [markdown]
# ## Cost / Loss function 설계

# %%
cost = tf.reduce_mean(tf.square(hypothesis - y_train))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26768\4252405856.py in <module>
# ----> 1 cost = tf.reduce_mean(tf.square(hypothesis - y_train))
#
# NameError: name 'tf' is not defined
