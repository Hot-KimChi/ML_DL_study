# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('6C1.csv')

time = np.array(range(1, len(data)+1))
time_scale = time * 0.01 * 0.000001

multiple = data[0]
waveform = []
for i in data:
    waveform.append(multiple*i)
    
fig, axs = plt.subplots(figsize=(20,10))
plt.plot(time_scale, waveform)
plt.scatter(time_scale, waveform)
plt.show()

# %%
a, b, c = map(int, input().split())

print(a+b+c)
# Out:
# 6

# %%
a, b = input().split()
print(int(a)+int(b))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4948\1392551533.py in <module>
# ----> 1 a, b = input().split()
#       2 print(int(a)+int(b))
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
a*b
a/b
a//b
a%b
# Out:
# 1

# %%
a = input()

print(a + '??1')
# Out:
# ??1

# %%
import numpy as np
chess = np.array([1,1,2,2,3,5])
in_chess = np.array(map(int, input().split()))
print(chessin_chess)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33824\323391554.py in <module>
#       2 chess = np.array([1,1,2,2,3,5])
#       3 in_chess = np.array(map(int, input().split()))
# ----> 4 print(chessin_chess)
#
# NameError: name 'chessin_chess' is not defined

# %%
## string --> int
a = int(input())

## string
b = input()

mul1 = a * int(b[2])
mul2 = a * int(b[1])
mul3 = a * int(b[0])
total = a * int(b)

print(mul1, total1 = str(mul2)+'0', mul3, sep='\n')
print(total)
# Out:
#   File "C:\Users\sel04327\AppData\Local\Temp\ipykernel_33824\736269986.py", line 12
#     print(mul1, total1 = str(mul2)+'0', mul3, sep='\n')
#                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
a, b = map(int, input().split())

if a > b:
    print('>')
elif a < b:
    print('<')
else:
    print('==')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33824\3064607142.py in <module>
# ----> 1 a, b = map(int, input().split())
#       2
#       3 if a > b:
#       4     print('>')
#       5 elif a < b:
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
a = int(input())

if a > 90 and a < 100:  
    print('A')
elif a > 80 and a < 89:
    print('F')
# Out:
# A
