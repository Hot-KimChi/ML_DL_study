# %% [markdown]
# >### Paper summary

# %%
from grobid_client import Client

client = Client(base_url="https://kermitt2-grobid.hf.space/api")

# %%
from pathlib import Path
from grobid_client.api.pdf import process_fulltext_document
from grobid_client.models import Article, ProcessForm
from grobid_client.types import TEI, File

paper_path = "Deep_Learning_in_Ultrasound.pdf"

pdf_file = Path(paper_path)

with pdf_file.open("rb") as fin:
    form = ProcessForm(
        input_=File(file_name=pdf_file.name, payload=fin, mime_type="application/pdf")
    )

    r = process_fulltext_document.sync_detailed(client=client, multipart_data=form)

    if r.is_success:
        article: Article = TEI.parse(r.content, figures=False)
        print('Done!')
    else:
        print('Error. Try again.')
# Out:
# Done!

# %%
article.title
# Out:
# 'Deep Learning in Ultrasound Imaging'

# %%
article.bibliography
# Out:
# Citation(main_title='Deep Learning in Ultrasound Imaging', authors=[Author(pers_name=PersName(firstname='Ruud', middlename='J G', surname='Van Sloun', title=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, suffix=<grobid_client.types.Unset object at 0x0000015D78CF2E50>), email=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, affiliations=<grobid_client.types.Unset object at 0x0000015D78CF2E50>), Author(pers_name=PersName(firstname='Regev', middlename=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, surname='Cohen', title=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, suffix=<grobid_client.types.Unset object at 0x0000015D78CF2E50>), email=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, affiliations=<grobid_client.types.Unset object at 0x0000015D78CF2E50>), Author(pers_name=PersName(firstname='Yonina', middlename='C', surname='Eldar', title=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, suffix=<grobid_client.types.Unset object 
# ...

# %%
article.citations
# Out:
# ArticleCitations(additional_properties={'b0': Citation(main_title=None, authors=[Author(pers_name=PersName(firstname='T', middlename='L', surname='Szabo', title=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, suffix=<grobid_client.types.Unset object at 0x0000015D78CF2E50>), email=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, affiliations=<grobid_client.types.Unset object at 0x0000015D78CF2E50>)], titles=CitationTitles(additional_properties={'m': 'Diagnostic Ultrasound Imaging: Inside Out'}), published=datetime.datetime(2004, 4, 20, 0, 0), publisher='Academic', scopes=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, ids=<grobid_client.types.Unset object at 0x0000015D78CF2E50>), 'b1': Citation(main_title='Design of low-cost portable ultrasound systems: Review', authors=[Author(pers_name=PersName(firstname='J', middlename='M', surname='Baran', title=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, suffix=<grobid_client.types.Unset object at 0x0000
# ...

# %%
article.sections
# Out:
# [Section(name='TITLE', num=<grobid_client.types.Unset object at 0x0000015D78CF2E50>, paragraphs=[TextWithRefs(text='Deep Learning in Ultrasound Imaging', refs=<grobid_client.types.Unset object at 0x0000015D78CF2E50>)]),
#  Section(name='ABSTRACT', num=None, paragraphs=[TextWithRefs(text='This article provides an overview of use of deep, data-driven learning strategies in ultrasound systems, from the front-end to advanced applications. The authors discuss the use of these new computational approaches in all aspects of ultrasound imaging, ranging from ideas that are at the interface of raw signal acquisition (including adaptive beam forming) and image formation, to learning compressive codes for color Doppler acquisition to learning strategies for performing clutter suppression.', refs=[])]),
# ...

# %%
import openai

openai.api_key = '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'

# %%
paragraph = ''

for p in article.sections[2].paragraphs:
    paragraph = paragraph + ' ' + p.text

paragraph = paragraph.strip()

paragraph
# Out:
# 'Diagnostic imaging plays a critical role in healthcare, serving as a fundamental asset for timely diagnosis, disease staging, and management, as well as for treatment choice, planning, guidance, and follow-up. Among the diagnostic imaging options, ultrasound imaging [1] is uniquely positioned, being a highly cost-effective modality that offers the clinician an unmatched and invaluable level of interaction, enabled by its real-time nature. Its portability and cost effectiveness permit point-of-care imaging at the bedside, in emergency settings, rural clinics, and developing countries. Ultrasonography is increasingly used across many medical specialties, spanning from obstetrics to cardiology and oncology, and its market share is globally growing. On the technological side, ultrasound probes are becoming increasingly compact and portable, with the market demand for low-cost "pocket-sized" devices expanding [2], [3]. Transducers are miniaturized, allowing, e.g., in-body imaging for int
# ...

# %%
len(paragraph.split(' '))
# Out:
# 486

# %%
messages = [{
        'role': 'system',
        'content': 'You are a helpful assistant for summarizing and translating research papers.'
    }, {
        'role': 'user',
        'content': f'50 단어로 요약해주세요: {paragraph}'
}]

res = openai.ChatCompletion.create(
    model='gpt-4',
    messages=messages
)

msg = res['choices'][0]['message']['content']

msg
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[11], line 9
#       1 messages = [{
#       2         'role': 'system',
#       3         'content': 'You are a helpful assistant for summarizing and translating research papers.'
#    (...)
#       6         'content': f'50 단어로 요약해주세요: {paragraph}'
#       7 }]
# ----> 9 res = openai.ChatCompletion.create(
#      10     model='gpt-4',
#      11     messages=messages
#      12 )
#      14 msg = res['choices'][0]['message']['content']
#      16 msg
#
# File c:\Users\sel04327\AppData\Local\Programs\Python\Python38\lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
# ...
