# %% [markdown]
# ##### 선형회귀일 경우,
# - 특성이 많을 수록 R^2 값이 엄청 올라간다.
# - 다중 회귀
#     - 여러 개의 특성을 사용한 선형 회귀를 다중 회귀(multiple regression)라고 한다.
#
# ![image.png](attachment:image.png)
#
# - 특성 공학(feature engineering)
#     - [농어 길이] x [농어 높이]를 새로운 특성으로 생성.
#     - 기존의 특성을 사용해 새로운 특성을 뽑아내는 작업을 특성 공학이라고 한다.

# %% [markdown]
# ##### 데이터 준비
# - 이전과 달리 농어의 특성이 3개로 늘어났기 때문에(길이 -> 길이, 높이, 두께)
# - 데이터를 복사해서 붙이는 작업을 numpy에서 잘 지원하지 않는다.
# - 판다스(Pandas)를 사용하면 아주 쉽게 해결 가능.
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('https://bit.ly/perch_csv')
print(df.head())

perch_full = df.to_numpy()
print(perch_full[:5])
# Out:
#    length   height   width
# 0     8.4     2.11    1.41
# 1    13.7     3.53    2.00
# 2    15.0     3.82    2.43
# 3    16.2     4.59    2.63
# 4    17.4     4.59    2.94
# [[ 8.4   2.11  1.41]
#  [13.7   3.53  2.  ]
#  [15.    3.82  2.43]
#  [16.2   4.59  2.63]
#  [17.4   4.59  2.94]]

# %%
perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(perch_full, perch_weight, random_state=42)

# %% [markdown]
# > polynomialFeatures 사용하기.

# %%
## polynomialFeatures 사용하기.
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# > PolynomialFeatures 예제 확인해 보기.

# %%
poly = PolynomialFeatures()
poly.fit([[2, 3]])
print(poly.transform([[2, 3]]))
# Out:
# [[1. 2. 3. 4. 6. 9.]]

# %% [markdown]
# ##### 훈련(fit)을 해야 변환(transform)이 가능합니다.
# - 혹은 fit_transform 사용가능.
