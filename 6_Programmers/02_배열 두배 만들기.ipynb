# %% [markdown]
# ![image.png](attachment:image-2.png)

# %%
def solution(numbers):
    
    ## numbers라는 list가 들어오기에 for문 돌려서 return
    answer = []
    for i in numbers:
        answer.append(i*2)
    return answer

solution([1,2,3,4,5])
# Out:
# [2, 4, 6, 8, 10]

# %%
def solution(numbers):
    return list(map(lambda x: x *2, numbers))

solution([1,2,3,4,5])
# Out:
# [2, 4, 6, 8, 10]
